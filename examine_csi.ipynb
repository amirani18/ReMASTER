# %%
import pickle
import qlib
import pandas as pd

with open(f'data/csi300/csi300_dl_train.pkl', 'rb') as f:
    dl_train = pickle.load(f)
    dl_train.data # a Pandas dataframe

dl_train.data.head
# dl_train.data.to_csv('csi300_dl_train.csv')
# Out:
# <bound method NDFrame.head of                                    feature                     \
#                       ($close-$open)/$open ($high-$low)/$open
# datetime   instrument
# 2008-01-02 SH600000               0.566957           1.770685
#            SH600001               1.749363           2.853979
#            SH600004               3.000000           1.686718
#            SH600005              -1.352733           0.845277
#            SH600006               0.692366           0.579018
# ...                                    ...                ...
# 2020-03-31 SZ300144              -0.519907           0.381621
#            SZ300347              -0.798496           0.868896
#            SZ300408              -0.884044           0.154063
#            SZ300413               0.075304           0.427410
#            SZ300498               2.567887           1.258494
#
#                                                          \
# ...

# %%
import pickle
import qlib
import pandas as pd

with open('C:\Users\amirani\ReMASTER\NQ100_dl_train.pkl', 'rb') as f:
    dl_train = pickle.load(f)
    # dl_train.data # a Pandas dataframe

# dl_train.to_csv('nq100_dl_train.csv')
dl_train.head()
dl_train.info
# dl_train.columns
# Out:
# <bound method DataFrame.info of                              feature                                          \
#                                 Time      Open      High       Low     Close
# Date
# 2019-08-11 23:05:00  8/11/2019 23:05   9073.25   9098.50   9073.00   9092.50
# 2019-08-11 23:10:00  8/11/2019 23:10   9093.25   9095.50   9089.75   9092.75
# 2019-08-11 23:15:00  8/11/2019 23:15   9093.00   9096.25   9088.00   9089.75
# 2019-08-11 23:20:00  8/11/2019 23:20   9090.25   9090.25   9086.00   9087.00
# 2019-08-11 23:25:00  8/11/2019 23:25   9086.75   9088.25   9079.75   9083.75
# ...                              ...       ...       ...       ...       ...
# 2022-03-30 22:40:00  3/30/2022 22:40  16548.50  16549.75  16545.75  16546.75
# 2022-03-30 22:45:00  3/30/2022 22:45  16546.75  16552.50  16546.00  16551.50
# 2022-03-30 22:50:00  3/30/2022 22:50  16551.75  16558.50  16549.50  16557.25
# 2022-03-30 22:55:00  3/30/2022 22:55  16556.75  16557.75  16554.00  16555.50
# ...
